# %% [markdown]
# ## Ejercicio 3
# Escribir una función que reciba un diccionario con las notas de los alumnos de un curso y devuelva una serie con las notas de los alumnos aprobados ordenadas de mayor a menor.

# %%
import pandas as pd

# %%
def is_aprobated(alumnos):
    alumnos = pd.Series(alumnos)
    alumnos = alumnos[alumnos>6] 
    return alumnos.sort_values(ascending=False)

if __name__=="__main__":
    calificaciones = {'Bogdan':5.4,'Fernanda':10.0,'Diego':7.2,'Delia': 9.3,'Alejandro':5.5} 
    print(is_aprobated(calificaciones))
# Out:
# Fernanda    10.0
# Delia        9.3
# Diego        7.2
# dtype: float64

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1e10aa03-2419-4c23-a4cc-d5f4e0f8511d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
